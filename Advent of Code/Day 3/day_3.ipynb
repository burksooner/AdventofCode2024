# %% [markdown]
# # Day 3 Part 1

# %%
import re

test = "xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))"

# Exact mul(1-3 digits, 1-3 digits) with no spaces
pattern = r"mul\((\d{1,3}),(\d{1,3})\)"

matches = re.findall(pattern, test)
print(matches)

def calculate_multiplication_sum(matches):
    # Calculate the products and sum them
    total = 0
    for match in matches:
        num1, num2 = int(match[0]), int(match[1])
        product = num1 * num2
        total += product
    
    print(f"\nTotal sum of all multiplications: {total}")
    return total
    
calculate_multiplication_sum(matches)
# Out:
# [('2', '4'), ('5', '5'), ('11', '8'), ('8', '5')]
#
# Total sum of all multiplications: 161
# 161

# %%
# now pull the input file
with open("day_3_inputs.txt", "r") as file:
    input_text = file.read()

matches = re.findall(pattern, input_text)
print(matches)

calculate_multiplication_sum(matches)
# Out:
# [('28', '510'), ('276', '283'), ('181', '314'), ('314', '733'), ('457', '651'), ('279', '135'), ('579', '740'), ('515', '329'), ('508', '45'), ('299', '897'), ('948', '555'), ('137', '832'), ('243', '401'), ('71', '774'), ('172', '268'), ('758', '223'), ('49', '326'), ('786', '646'), ('841', '587'), ('981', '592'), ('296', '234'), ('714', '304'), ('757', '667'), ('12', '277'), ('540', '166'), ('286', '138'), ('770', '494'), ('457', '109'), ('436', '361'), ('899', '657'), ('965', '550'), ('16', '267'), ('305', '656'), ('795', '461'), ('647', '388'), ('944', '963'), ('856', '379'), ('185', '846'), ('460', '898'), ('229', '900'), ('990', '969'), ('927', '423'), ('827', '259'), ('771', '396'), ('31', '548'), ('186', '978'), ('893', '833'), ('151', '691'), ('519', '18'), ('424', '339'), ('557', '339'), ('742', '360'), ('793', '965'), ('147', '180'), ('321', '646'), ('365', '934'), ('324', '81'), ('932', '108'), ('496', '552'), ('339', '910'), ('117', '662'), ('609', '660'), ('920', '151'), ('814', '176'), ('768', '67'), ('648', '959'), ('981', '526'), ('382', '736'), ('827', '552'), ('275', '49'), ('115', '651'), ('432', '848'), ('908', '784'), ('991', '570'), ('347', '128'), ('472', '42'), ('398', '263'), ('635', '53'), ('536', '9'), ('605', '574'), ('552', '978'), ('297', '553'), ('376', '496'), ('802', '270'), ('74', '384'), ('432', '177'), ('874', '804'), ('813', '911'), ('386', '887'), ('883', '274'), ('725', '452'), ('543', '116'), ('319', '593'), ('148', '463'), ('394', '10'), ('692', '431'), ('148', '193'), ('467', '891'), ('694', '600'), ('326', '593'), ('485', '524'), ('111', '647'), ('906', '376'), ('503', '859'), ('264', '7'), ('995', '183'), ('700', '292'), ('583', '912'), ('69', '943'), ('241', '860'), ('481', '928'), ('543', '18'), ('147', '812'), ('503', '199'), ('779', '22'), ('462', '626'), ('585', '629'), ('353', '894'), ('539', '201'), ('767', '323'), ('330', '946'), ('377', '867'), ('410', '38'), ('557', '508'), ('296', '240'), ('269', '24'), ('444', '457'), ('42', '768'), ('425', '243'), ('958', '793'), ('973', '632'), ('870', '593'), ('745', '223'), ('181', '897'), ('673', '429'), ('102', '654'), ('536', '134'), ('862', '564'), ('573', '681'), ('469', '457'), ('305', '833'), ('56', '269'), ('156', '371'), ('538', '775'), ('376', '766'), ('605', '700'), ('709', '480'), ('56', '9'), ('41', '872'), ('533', '809'), ('473', '210'), ('828', '843'), ('351', '567'), ('312', '118'), ('371', '16'), ('987', '14'), ('526', '248'), ('765', '913'), ('681', '758'), ('780', '610'), ('880', '694'), ('877', '703'), ('61', '42'), ('711', '20'), ('467', '353'), ('27', '818'), ('672', '30'), ('750', '564'), ('885', '22'), ('288', '143'), ('991', '738'), ('759', '758'), ('219', '736'), ('835', '869'), ('980', '700'), ('258', '59'), ('25', '617'), ('122', '300'), ('756', '549'), ('903', '219'), ('15', '106'), ('165', '663'), ('380', '460'), ('83', '41'), ('514', '603'), ('433', '234'), ('886', '132'), ('307', '385'), ('225', '698'), ('44', '530'), ('66', '204'), ('712', '389'), ('983', '178'), ('135', '631'), ('420', '746'), ('880', '917'), ('91', '172'), ('682', '688'), ('547', '808'), ('232', '866'), ('179', '173'), ('153', '382'), ('386', '581'), ('914', '537'), ('694', '671'), ('423', '141'), ('475', '67'), ('801', '43'), ('323', '862'), ('575', '460'), ('328', '263'), ('68', '15'), ('933', '744'), ('926', '9'), ('430', '387'), ('146', '810'), ('261', '638'), ('968', '916'), ('392', '73'), ('283', '731'), ('533', '13'), ('128', '902'), ('358', '310'), ('845', '59'), ('466', '598'), ('462', '461'), ('102', '119'), ('295', '640'), ('238', '80'), ('604', '585'), ('268', '333'), ('608', '489'), ('392', '877'), ('255', '616'), ('124', '352'), ('847', '267'), ('539', '980'), ('333', '440'), ('648', '382'), ('953', '202'), ('561', '38'), ('743', '854'), ('471', '909'), ('69', '900'), ('856', '5'), ('283', '77'), ('764', '834'), ('466', '722'), ('903', '291'), ('573', '842'), ('628', '338'), ('776', '642'), ('362', '353'), ('378', '420 ...
#
# Total sum of all multiplications: 162813399
# 162813399

# %% [markdown]
# # Part 2

# %%
test = "xmul(2,4)&mul[3,7]!^don't()_mul(5,5)+mul(32,64](mul(11,8)undo()?mul(8,5))"

# %%
def process_multiplication_commands(text_to_process):
    # Find all do/don't control commands and their positions in text
    # Returns list of tuples: (position, True if 'do', False if 'don't')
    control_command_positions = [(m.start(), m.group(1) == 'do') 
                               for m in re.finditer(r"(do|don't)\((.*?)\)", text_to_process)]
    print("\nControl commands found:", control_command_positions)
    
    # Find all multiplication expressions like mul(x,y)
    multiplication_expressions = list(re.finditer(pattern, text_to_process))
    print("\nMultiplication expressions found:", [expr.groups() for expr in multiplication_expressions])
    
    # If no control commands found, process all multiplications
    if not control_command_positions:
        print("\nNo control commands found - processing all multiplications")
        return calculate_multiplication_sum([expr.groups() for expr in multiplication_expressions])

    valid_multiplications = []
    multiplication_enabled = True  # Default state is enabled
    current_control_index = 0

    # Process each multiplication based on preceding control commands
    for mul_expr in multiplication_expressions:
        # Check all control commands that come before this multiplication
        while (current_control_index < len(control_command_positions) and 
               control_command_positions[current_control_index][0] < mul_expr.start()):
            # Update enabled state based on control command
            multiplication_enabled = control_command_positions[current_control_index][1]
            current_control_index += 1
        
        # If multiplications are enabled, add this expression to valid list
        if multiplication_enabled:
            valid_multiplications.append(mul_expr.groups())
            print(f"\nAdded valid multiplication: {mul_expr.groups()}")
        else:
            print(f"\nSkipped multiplication: {mul_expr.groups()} (multiplication disabled)")

    print("\nFinal list of valid multiplications:", valid_multiplications)
    return calculate_multiplication_sum(valid_multiplications)

# Calculate sum of all valid multiplications in input text
result = process_multiplication_commands(input_text)
print("\nFinal result:", result)
# Out:
# Control commands found: [(300, True), (459, True), (977, True), (1224, False), (1406, False), (1533, True), (1670, False), (2502, True), (2567, True), (2746, False), (3120, False), (3327, True), (4098, False), (4603, True), (4666, False), (5297, True), (5613, False), (5723, True), (5841, True), (5879, True), (6164, False), (6416, True), (6450, True), (6515, False), (7029, True), (7480, False), (7830, True), (7956, True), (8080, True), (8171, False), (8216, False), (8348, False), (8694, True), (8811, True), (8869, True), (8940, True), (9228, False), (9345, True), (9426, False), (10165, False), (11517, False), (12119, False), (12981, True), (13037, False), (14133, False), (14211, False), (14530, False), (14778, True), (15018, False), (15247, True), (15995, False), (16317, True), (16618, True), (16755, True), (16885, False), (17399, False), (17452, True), (17590, False), (18486, False)]
#
# Multiplication expressions found: [('28', '510'), ('276', '283'), ('181', '314'), ('314', '733'), ('457', '651'), ('279', '135'), ('579', '740'), ('515', '329'), ('508', '45'), ('299', '897'), ('948', '555'), ('137', '832'), ('243', '401'), ('71', '774'), ('172', '268'), ('758', '223'), ('49', '326'), ('786', '646'), ('841', '587'), ('981', '592'), ('296', '234'), ('714', '304'), ('757', '667'), ('12', '277'), ('540', '166'), ('286', '138'), ('770', '494'), ('457', '109'), ('436', '361'), ('899', '657'), ('965', '550'), ('16', '267'), ('305', '656'), ('795', '461'), ('647', '388'), ('944', '963'), ('856', '379'), ('185', '846'), ('460', '898'), ('229', '900'), ('990', '969'), ('927', '423'), ('827', '259'), ('771', '396'), ('31', '548'), ('186', '978'), ('893', '833'), ('151', '691'), ('519', '18'), ('424', '339'), ('557', '339'), ('742', '360'), ('793', '965'), ('147', '180'), ('321', '646'), ('365', '934'), ('324', '81'), ('932', '108'), ('496', '552'), ('339', '910'), ('117', '662'), ('609', '660'), ('920', '151'), ('814', '176'), ('768', '67'), ('648', '959'), ('981', '526'), ('382', '736'), ('827', '552'), ('275', '49'), ('115', '651'), ('432', '848'), ('908', '784'), ('991', '570'), ('347', '128'), ('472', '42'), ('398', '263'), ('635', '53'), ('536', '9'), ('605', '574'), ('552', '978'), ('297', '553'), ('376', '496'), ('802', '270'), ('74', '384'), ('432', '177'), ('874', '804'), ('813', '911'), ('386', '887'), ('883', '274'), ('725', '452'), ('543', '116'), ('319', '593'), ('148', '463'), ('394', '10'), ('692', '431'), ('148', '193'), ('467', '891'), ('694', '600'), ('326', '593'), ('485', '524'), ('111', '647'), ('906', '376'), ('503', '859'), ('264', '7'), ('995', '183'), ('700', '292'), ('583', '912'), ('69', '943'), ('241', '860'), ('481', '928'), ('543', '18'), ('147', '812'), ('503', '199'), ('779', '22'), ('462', '626'), ('585', '629'), ('353', '894'), ('539', '201'), ('767', '323'), ('330', '946'), ('377', '867'), ('410', '38'), ('557', '508'), ('296', '240'), ('269', '24'), ('444', '457'), ('42', '768'), ('425', '243'), ('958', '793'), ('973', '632'), ('870', '593'), ('745', '223'), ('181', '897'), ('673', '429'), ('102', '654'), ('536', '134'), ('862', '564'), ('573', '681'), ('469', '457'), ('305', '833'), ('56', '269'), ('156', '371'), ('538', '775'), ('376', '766'), ('605', '700'), ('709', '480'), ('56', '9'), ('41', '872'), ('533', '809'), ('473', '210'), ('828', '843'), ('351', '567'), ('312', '118'), ('371', '16'), ('987', '14'), ('526', '248'), ('765', '913'), ('681', '758'), ('780', '610'), ('880', '694'), ('877', '703'), ('61', '42'), ('711', '20'), ('467', '353'), ('27', '818'), ('672', '30'), ('750', '564'), ('885', '22'), ('288', '143'), ('991', '738'), ('759', '758'), ('219', '736'), ('835', '869'), ('980', '700'), ('258', '59'), ('25', '617'), ('122', '300'), ('756', '549'), ('903', '219'), ('15', '106'), ('165', '663'), ('380', '460'), ('83', '41'), ('514', '603'), ('433', '234'), ('886', '132'), ('307', '385'), ('225', '698'), ('44', '530'), ('66', '204'), ('712', '389'), ('983', '178'), ('135', '631'), ('420', '746'), ('880', '917'), ('91', '172'), ('682', '688'), ('547', '808'), ('232', '866'), ('179', '173'), ('153', '382'), ('386', '581'), ('914', '537'), ('694', '671'), ('423', '141'), ('475', '67'), ('801', '43'), ('323', '862'), ('575', '460'), ('328', '263'), ('68', '15'), ('933', '744'), ('926', '9'), ('430', '387'), ('146', '810'), ('261', '638'), ('968', '916'), ('392', '73'), ('283', '731'), ('533', '13'), ('128', '902'), ('358', '310'), ('845', '59'), ('466', '598'), ('462', '461'), ('102', '119'), ('295', '640'), ('238', '80'), ('604', '585'), ('268', '333'), ('608', '489'), ('392', '877'), ('255', '616'), ('124', '352'), ('847', '267'), ('539', '980'), ('333', '440'), ('648', '382'), ('953', '202'), ('561', '38'), ('743', '854'), ('471', '909'), ('69', '900'), ('856', '5'), ('283', '77'), ('764', '834'), ('466', '722'), ('903', '291'), ('573', '842'), ('628', '338'), ('776', '6 ...
#
# Added valid multiplication: ('28', '510')
#
# Added valid multiplication: ('276', '283')
#
# Added valid multiplication: ('181', '314')
#
# Added valid multiplication: ('314', '733')
#
# Added valid multiplication: ('457', '651')
#
# Added valid multiplication: ('279', '135')
#
# Added valid multiplication: ('579', '740')
#
# Added valid multiplication: ('515', '329')
#
# Added valid multiplication: ('508', '45')
#
# Added valid multiplication: ('299', '897')
#
# Added valid multiplication: ('948', '555')
#
# Added valid multiplication: ('137', '832')
#
# Added valid multiplication: ('243', '401')
#
# Added valid multiplication: ('71', '774')
#
# Added valid multiplication: ('172', '268')
#
# Added valid multiplication: ('758', '223')
#
# Added valid multiplication: ('49', '326')
#
# Added valid multiplication: ('786', '646')
#
# Added valid multiplication: ('841', '587')
#
# Added valid multiplication: ('981', '592')
#
# Added valid multiplication: ('296', '234')
#
# Added valid multiplication: ('714', '304')
#
# Added valid multiplication: ('757', '667')
#
# Added valid multiplication: ('12', '277')
#
# Added valid multiplication: ('540', '166')
#
# Added valid multiplication: ('286', '138')
#
# Added valid multiplication: ('770', '494')
#
# Added valid multiplication: ('457', '109')
#
# Added valid multiplication: ('436', '361')
#
# Added valid multiplication: ('899', '657')
#
# Added valid multiplication: ('965', '550')
#
# Added valid multiplication: ('16', '267')
#
# Added valid multiplication: ('305', '656')
#
# Added valid multiplication: ('795', '461')
#
# Added valid multiplication: ('647', '388')
#
# Added valid multiplication: ('944', '963')
#
# Added valid multiplication: ('856', '379')
#
# Added valid multiplication: ('185', '846')
#
# Added valid multiplication: ('460', '898')
#
# Added valid multiplication: ('229', '900')
#
# Added valid multiplication: ('990', '969')
#
# Added valid multiplication: ('927', '423')
#
# Added valid multiplication: ('827', '259')
#
# Added valid multiplication: ('771', '396')
#
# Added valid multiplication: ('31', '548')
#
# Added valid multiplication: ('186', '978')
#
# Added valid multiplication: ('893', '833')
#
# Added valid multiplication: ('151', '691')
#
# Skipped multiplication: ('519', '18') (multiplication disabled)
#
# Skipped multiplication: ('424', '339') (multiplication disabled)
#
# Skipped multiplication: ('557', '339') (multiplication disabled)
#
# Skipped multiplication: ('742', '360') (multiplication disabled)
#
# Skipped multiplication: ('793', '965') (multiplication disabled)
#
# Skipped multiplication: ('147', '180') (multiplication disabled)
#
# Skipped multiplication: ('321', '646') (multiplication disabled)
#
# Skipped multiplication: ('365', '934') (multiplication disabled)
#
# Skipped multiplication: ('324', '81') (multiplication disabled)
#
# Skipped multiplication: ('932', '108') (multiplication disabled)
#
# Skipped multiplication: ('496', '552') (multiplication disabled)
#
# Skipped multiplication: ('339', '910') (multiplication disabled)
#
# Added valid multiplication: ('117', '662')
#
# Added valid multiplication: ('609', '660')
#
# Added valid multiplication: ('920', '151')
#
# Skipped multiplication: ('814', '176') (multiplication disabled)
#
# Skipped multiplication: ('768', '67') (multiplication disabled)
#
# Skipped multiplication: ('648', '959') (multiplication disabled)
#
# Skipped multiplication: ('981', '526') (multiplication disabled)
#
# Skipped multiplication: ('382', '736') (multiplication disabled)
#
# Skipped multiplication: ('827', '552') (multiplication disabled)
#
# Skipped multiplication: ('275', '49') (multiplication disabled)
#
# Skipped multiplication: ('115', '651') (multiplication disabled)
#
# Skipped multiplication: ('432', '848') (multiplication disabled)
#
# Skipped multiplication: ('908', '784') (multiplication disabled)
#
# Skipped multiplication: ('991', '570') (multiplication disabled)
#
# Skipped multiplication: ('347', '128') (multiplication disabled)
#
# Skipped multiplication: ('472', '42') (multiplication disabled)
#
# Skipped multiplication: ('398', '263') (multiplication disabled)
#
# Skipped multiplication: ('635', '53') (multiplication disabled)
#
# Skipped multiplication: ('536', '9') (multiplication disabled)
#
# Skipped multiplication: ('605', '574') (multiplication disabled)
#
# Skipped multiplication: ('552', '978') (multiplication disabled)
#
# Skipped multiplication: ('297', '553') (multiplication disabled)
#
# Skipped multiplication: ('376', '496') (multiplication disabled)
#
# Skipped multiplication: ('802', '270') (multiplication disabled)
#
# Skipped multiplication: ('74', '384') (multiplication disabled)
#
# Skipped multiplication: ('432', '177') (multiplication disabled)
#
# Skipped multiplication: ('874', '804') (multiplication disabled)
#
# Skipped multiplication: ('813', '911') (multiplication disabled)
#
# Skipped multiplication: ('386', '887') (multiplication disabled)
#
# Skipped multiplication: ('883', '274') (multiplication disabled)
#
# Skipped multiplication: ('725', '452') (multiplication disabled)
#
# Skipped multiplication: ('543', '116') (multiplication disabled)
#
# Skipped multiplication: ('319', '593') (multiplication disabled)
#
# Added valid multiplication: ('148', '463')
#
# Added valid multiplication: ('394', '10')
#
# Added valid multiplication: ('692', '431')
#
# Added valid multiplication: ('148', '193')
#
# Added valid multiplication: ('467', '891')
#
# Added valid multiplication: ('694', '600')
#
# Added valid multiplication: ('326', '593')
#
# Added valid multiplication: ('485', '524')
#
# Skipped multiplication: ('111', '647') (multiplication disabled)
#
# Skipped multiplication: ('906', '376') (multiplication disabled)
#
# Skipped multiplication: ('503', '859') (multiplication disabled)
#
# Skipped multiplication: ('264', '7') (multiplication disabled)
#
# Skipped multiplication: ('995', '183') (multiplication disabled)
#
# Skipped multiplication: ('700', '292') (multiplication disabled)
#
# Skipped multiplication: ('583', '912') (multiplication disabled)
#
# Skipped multiplication: ('69', '943') (multiplication disabled)
#
# Skipped multiplication: ('241', '860') (multiplication disabled)
#
# Skipped multiplication: ('481', '928') (multiplication disabled)
#
# Skipped multiplication: ('543', '18') (multiplication disabled)
#
# Skipped multiplication: ('147', '812') (multiplication disabled)
#
# Skipped multiplication: ('503', '199') (multiplication disabled)
#
# Skipped multiplication: ('779', '22') (multiplication disabled)
#
# Skipped multiplication: ('462', '626') (multiplication disabled)
#
# Skipped multiplication: ('585', '629') (multiplication disabled)
#
# Skipped multiplication: ('353', '894') (multiplication disabled)
#
# Skipped multiplication: ('539', '201') (multiplication disabled)
#
# Skipped multiplication: ('767', '323') (multiplication disabled)
#
# Added valid multiplication: ('330', '946')
#
# Added valid multiplication: ('377', '867')
#
# Added valid multiplication: ('410', '38')
#
# Added valid multiplication: ('557', '508')
#
# Added valid multiplication: ('296', '240')
#
# Added valid multiplication: ('269', '24')
#
# Added valid multiplication: ('444', '457')
#
# Added valid multiplication: ('42', '768')
#
# Added valid multiplication: ('425', '243')
#
# Added valid multiplication: ('958', '793')
#
# Added valid multiplication: ('973', '632')
#
# Added valid multiplication: ('870', '593')
#
# Added valid multiplication: ('745', '223')
#
# Added valid multiplication: ('181', '897')
#
# Added valid multiplication: ('673', '429')
#
# Added valid multiplication: ('102', '654')
#
# Added valid multiplication: ('536', '134')
#
# Added valid multiplication: ('862', '564')
#
# Added valid multiplication: ('573', '681')
#
# Added valid multiplication: ('469', '457')
#
# Added valid multiplication: ('305', '833')
#
# Added valid multiplication: ('56', '269')
#
# Added valid multiplication: ('156', '371')
#
# Added valid multiplication: ('538', '775')
#
# Added valid multiplication: ('376', '766')
#
# Added valid multiplication: ('605', '700')
#
# Added valid multiplication: ('709', '480')
#
# Added valid multiplication: ('56', '9')
#
# Added valid multiplication: ('41', '872')
#
# Added valid multiplication: ('533', '809')
#
# Added valid multiplication: ('473', '210')
#
# Added valid multiplication: ('828', '843')
#
# Skipped multiplication: ('351', '567') (multiplication disabled)
#
# Skipped multiplication: ('312', '118') (multiplication disabled)
#
# Skipped multiplication: ('371', '16') (multiplication disabled)
#
# Skipped multiplication: ('987', '14') (multiplication disabled)
#
# Skipped multiplication: ('526', '248') (multiplication disabled)
#
# Skipped multiplication: ('765', '913') (multiplication disabled)
#
# Skipped multiplication: ('681', '758') (multiplication disabled)
#
# Skipped multiplication: ('780', '610') (multiplication disabled)
#
# Skipped multiplication: ('880', '694') (multiplication disabled)
#
# Skipped multiplication: ('877', '703') (multiplication disabled)
#
# Skipped multiplication: ('61', '42') (multiplication disabled)
#
# Skipped multiplication: ('711', '20') (multiplication disabled)
#
# Skipped multiplication: ('467', '353') (multiplication disabled)
#
# Skipped multiplication: ('27', '818') (multiplication disabled)
#
# Skipped multiplication: ('672', '30') (multiplication disabled)
#
# Skipped multiplication: ('750', '564') (multiplication disabled)
#
# Skipped multiplication: ('885', '22') (multiplication disabled)
#
# Added valid multiplication: ('288', '143')
#
# Added valid multiplication: ('991', '738')
#
# Skipped multiplication: ('759', '758') (multiplication disabled)
#
# Skipped multiplication: ('219', '736') (multiplication disabled)
#
# Skipped multiplication: ('835', '869') (multiplication disabled)
#
# Skipped multiplication: ('980', '700') (multiplication disabled)
#
# Skipped multiplication: ('258', '59') (multiplication disabled)
#
# Skipped multiplication: ('25', '617') (multiplication disabled)
#
# Skipped multiplication: ('122', '300') (multiplication disabled)
#
# Skipped multiplication: ('756', '549') (multiplication disabled)
#
# Skipped multiplication: ('903', '219') (multiplication disabled)
#
# Skipped multiplication: ('15', '106') (multiplication disabled)
#
# Skipped multiplication: ('165', '663') (multiplication disabled)
#
# Skipped multiplication: ('380', '460') (multiplication disabled)
#
# Skipped multiplication: ('83', '41') (multiplication disabled)
#
# Skipped multiplication: ('514', '603') (multiplication disabled)
#
# Skipped multiplication: ('433', '234') (multiplication disabled)
#
# Skipped multiplication: ('886', '132') (multiplication disabled)
#
# Skipped multiplication: ('307', '385') (multiplication disabled)
#
# Skipped multiplication: ('225', '698') (multiplication disabled)
#
# Skipped multiplication: ('44', '530') (multiplication disabled)
#
# Skipped multiplication: ('66', '204') (multiplication disabled)
#
# Skipped multiplication: ('712', '389') (multiplication disabled)
#
# Skipped multiplication: ('983', '178') (multiplication disabled)
#
# Skipped multiplication: ('135', '631') (multiplication disabled)
#
# Skipped multiplication: ('420', '746') (multiplication disabled)
#
# Skipped multiplication: ('880', '917') (multiplication disabled)
#
# Skipped multiplication: ('91', '172') (multiplication disabled)
#
# Skipped multiplication: ('682', '688') (multiplication disabled)
#
# Added valid multiplication: ('547', '808')
#
# Added valid multiplication: ('232', '866')
#
# Added valid multiplication: ('179', '173')
#
# Added valid multiplication: ('153', '382')
#
# Added valid multiplication: ('386', '581')
#
# Added valid multiplication: ('914', '537')
#
# Added valid multiplication: ('694', '671')
#
# Added valid multiplication: ('423', '141')
#
# Added valid multiplication: ('475', '67')
#
# Added valid multiplication: ('801', '43')
#
# Added valid multiplication: ('323', '862')
#
# Added valid multiplication: ('575', '460')
#
# Added valid multiplication: ('328', '263')
#
# Added valid multiplication: ('68', '15')
#
# Skipped multiplication: ('933', '744') (multiplication disabled)
#
# Skipped multiplication: ('926', '9') (multiplication disabled)
#
# Added valid multiplication: ('430', '387')
#
# Added valid multiplication: ('146', '810')
#
# Added valid multiplication: ('261', '638')
#
# Added valid multiplication: ('968', '916')
#
# Added valid multiplication: ('392', '73')
#
# Added valid multiplication: ('283', '731')
#
# Added valid multiplication: ('533', '13')
#
# Added valid multiplication: ('128', '902')
#
# Added valid multiplication: ('358', '310')
#
# Added valid multiplication: ('845', '59')
#
# Added valid multiplication: ('466', '598')
#
# Added valid multiplication: ('462', '461')
#
# Added valid multiplication: ('102', '119')
#
# Added valid multiplication: ('295', '640')
#
# Added valid multiplication: ('238', '80')
#
# Skipped multiplication: ('604', '585') (multiplication disabled)
#
# Skipped multiplication: ('268', '333') (multiplication disabled)
#
# Skipped multiplication: ('608', '489') (multiplication disabled)
#
# Skipped multiplication: ('392', '877') (multiplication disabled)
#
# Skipped multiplication: ('255', '616') (multiplication disabled)
#
# Skipped multiplication: ('124', '352') (multiplication disabled)
#
# Skipped multiplication: ('847', '267') (multiplication disabled)
#
# Skipped multiplication: ('539', '980') (multiplication disabled)
#
# Skipped multiplication: ('333', '440') (multiplication disabled)
#
# Skipped multiplication: ('648', '382') (multiplication disabled)
#
# Skipped multiplication: ('953', '202') (multiplication disabled)
#
# Skipped multiplication: ('561', '38') (multiplication disabled)
#
# Added valid multiplication: ('743', '854')
#
# Added valid multiplication: ('471', '909')
#
# Added valid multiplication: ('69', '900')
#
# Added valid multiplication: ('856', '5')
#
# Skipped multiplication: ('283', '77') (multiplication disabled)
#
# Skipped multiplication: ('764', '834') (multiplication disabled)
#
# Skipped multiplication: ('466', '722') (multiplication disabled)
#
# Skipped multiplication: ('903', '291') (multiplication disabled)
#
# Skipped multiplication: ('573', '842') (multiplication disabled)
#
# Skipped multiplication: ('628', '338') (multiplication disabled)
#
# Skipped multiplication: ('776', '642') (multiplication disabled)
#
# Skipped multiplication: ('362', '353') (multiplication disabled)
#
# Skipped multiplication: ('378', '420') (multiplication disabled)
#
# Skipped multiplication: ('444', '413') (multiplication disabled)
#
# Skipped multiplication: ('620', '723') (multiplication disabled)
#
# Skipped multiplication: ('192', '63') (multiplication disabled)
#
# Skipped multiplication: ('662', '913') (multiplication disabled)
#
# Skipped multiplication: ('955', '636') (multiplication disabled)
#
# Skipped multiplication: ('92', '704') (multiplication disabled)
#
# Skipped multiplication: ('234', '600') (multiplication disabled)
#
# Skipped multiplication: ('905', '911') (multiplication disabled)
#
# Skipped multiplication: ('854', '919') (multiplication disabled)
#
# Skipped multiplication: ('321', '842') (multiplication disabled)
#
# Skipped multiplication: ('636', '225') (multiplication disabled)
#
# Skipped multiplication: ('984', '80') (multiplication disabled)
#
# Added valid multiplication: ('521', '403')
#
# Added valid multiplication: ('156', '80')
#
# Added valid multiplication: ('612', '943')
#
# Added valid multiplication: ('209', '98')
#
# Added valid multiplication: ('866', '416')
#
# Added valid multiplication: ('190', '400')
#
# Added valid multiplication: ('243', '292')
#
# Added valid multiplication: ('497', '592')
#
# Added valid multiplication: ('890', '938')
#
# Added valid multiplication: ('384', '970')
#
# Added valid multiplication: ('662', '264')
#
# Added valid multiplication: ('907', '796')
#
# Added valid multiplication: ('819', '58')
#
# Added valid multiplication: ('962', '712')
#
# Skipped multiplication: ('142', '759') (multiplication disabled)
#
# Skipped multiplication: ('588', '670') (multiplication disabled)
#
# Skipped multiplication: ('666', '177') (multiplication disabled)
#
# Skipped multiplication: ('185', '320') (multiplication disabled)
#
# Skipped multiplication: ('955', '648') (multiplication disabled)
#
# Skipped multiplication: ('871', '657') (multiplication disabled)
#
# Skipped multiplication: ('489', '12') (multiplication disabled)
#
# Skipped multiplication: ('321', '797') (multiplication disabled)
#
# Skipped multiplication: ('199', '482') (multiplication disabled)
#
# Skipped multiplication: ('479', '996') (multiplication disabled)
#
# Skipped multiplication: ('183', '994') (multiplication disabled)
#
# Skipped multiplication: ('650', '139') (multiplication disabled)
#
# Skipped multiplication: ('336', '775') (multiplication disabled)
#
# Skipped multiplication: ('840', '883') (multiplication disabled)
#
# Skipped multiplication: ('617', '724') (multiplication disabled)
#
# Added valid multiplication: ('967', '248')
#
# Added valid multiplication: ('142', '596')
#
# Added valid multiplication: ('300', '181')
#
# Added valid multiplication: ('688', '281')
#
# Added valid multiplication: ('393', '337')
#
# Added valid multiplication: ('86', '734')
#
# Added valid multiplication: ('680', '335')
#
# Added valid multiplication: ('525', '510')
#
# Added valid multiplication: ('273', '72')
#
# Added valid multiplication: ('874', '891')
#
# Skipped multiplication: ('425', '997') (multiplication disabled)
#
# Skipped multiplication: ('715', '75') (multiplication disabled)
#
# Skipped multiplication: ('42', '172') (multiplication disabled)
#
# Skipped multiplication: ('43', '709') (multiplication disabled)
#
# Skipped multiplication: ('96', '171') (multiplication disabled)
#
# Skipped multiplication: ('630', '90') (multiplication disabled)
#
# Skipped multiplication: ('857', '733') (multiplication disabled)
#
# Skipped multiplication: ('696', '649') (multiplication disabled)
#
# Skipped multiplication: ('237', '252') (multiplication disabled)
#
# Skipped multiplication: ('719', '330') (multiplication disabled)
#
# Skipped multiplication: ('297', '511') (multiplication disabled)
#
# Skipped multiplication: ('296', '219') (multiplication disabled)
#
# Skipped multiplication: ('106', '612') (multiplication disabled)
#
# Skipped multiplication: ('465', '917') (multiplication disabled)
#
# Added valid multiplication: ('395', '446')
#
# Added valid multiplication: ('883', '551')
#
# Added valid multiplication: ('840', '262')
#
# Added valid multiplication: ('593', '805')
#
# Added valid multiplication: ('458', '211')
#
# Added valid multiplication: ('804', '650')
#
# Added valid multiplication: ('708', '773')
#
# Added valid multiplication: ('987', '695')
#
# Added valid multiplication: ('130', '150')
#
# Added valid multiplication: ('311', '404')
#
# Added valid multiplication: ('382', '827')
#
# Added valid multiplication: ('128', '276')
#
# Added valid multiplication: ('963', '658')
#
# Added valid multiplication: ('107', '773')
#
# Added valid multiplication: ('851', '408')
#
# Added valid multiplication: ('84', '253')
#
# Added valid multiplication: ('207', '430')
#
# Added valid multiplication: ('727', '290')
#
# Added valid multiplication: ('629', '48')
#
# Added valid multiplication: ('437', '164')
#
# Skipped multiplication: ('220', '222') (multiplication disabled)
#
# Skipped multiplication: ('511', '928') (multiplication disabled)
#
# Skipped multiplication: ('5', '656') (multiplication disabled)
#
# Skipped multiplication: ('505', '334') (multiplication disabled)
#
# Added valid multiplication: ('520', '790')
#
# Skipped multiplication: ('445', '857') (multiplication disabled)
#
# Skipped multiplication: ('575', '75') (multiplication disabled)
#
# Skipped multiplication: ('243', '721') (multiplication disabled)
#
# Skipped multiplication: ('825', '189') (multiplication disabled)
#
# Skipped multiplication: ('565', '221') (multiplication disabled)
#
# Skipped multiplication: ('788', '786') (multiplication disabled)
#
# Skipped multiplication: ('886', '540') (multiplication disabled)
#
# Skipped multiplication: ('835', '804') (multiplication disabled)
#
# Skipped multiplication: ('273', '795') (multiplication disabled)
#
# Skipped multiplication: ('259', '67') (multiplication disabled)
#
# Skipped multiplication: ('278', '456') (multiplication disabled)
#
# Skipped multiplication: ('609', '189') (multiplication disabled)
#
# Skipped multiplication: ('594', '207') (multiplication disabled)
#
# Skipped multiplication: ('329', '470') (multiplication disabled)
#
# Skipped multiplication: ('5', '828') (multiplication disabled)
#
# Skipped multiplication: ('97', '709') (multiplication disabled)
#
# Skipped multiplication: ('697', '401') (multiplication disabled)
#
# Skipped multiplication: ('410', '704') (multiplication disabled)
#
# Skipped multiplication: ('236', '590') (multiplication disabled)
#
# Skipped multiplication: ('980', '340') (multiplication disabled)
#
# Skipped multiplication: ('739', '332') (multiplication disabled)
#
# Skipped multiplication: ('418', '580') (multiplication disabled)
#
# Skipped multiplication: ('607', '270') (multiplication disabled)
#
# Skipped multiplication: ('734', '771') (multiplication disabled)
#
# Skipped multiplication: ('114', '409') (multiplication disabled)
#
# Skipped multiplication: ('287', '279') (multiplication disabled)
#
# Skipped multiplication: ('352', '591') (multiplication disabled)
#
# Skipped multiplication: ('80', '771') (multiplication disabled)
#
# Skipped multiplication: ('730', '246') (multiplication disabled)
#
# Skipped multiplication: ('737', '598') (multiplication disabled)
#
# Skipped multiplication: ('488', '879') (multiplication disabled)
#
# Skipped multiplication: ('132', '483') (multiplication disabled)
#
# Skipped multiplication: ('472', '358') (multiplication disabled)
#
# Skipped multiplication: ('840', '726') (multiplication disabled)
#
# Skipped multiplication: ('290', '835') (multiplication disabled)
#
# Skipped multiplication: ('399', '896') (multiplication disabled)
#
# Skipped multiplication: ('602', '533') (multiplication disabled)
#
# Skipped multiplication: ('784', '971') (multiplication disabled)
#
# Skipped multiplication: ('473', '91') (multiplication disabled)
#
# Skipped multiplication: ('599', '390') (multiplication disabled)
#
# Skipped multiplication: ('195', '251') (multiplication disabled)
#
# Skipped multiplication: ('801', '341') (multiplication disabled)
#
# Skipped multiplication: ('130', '592') (multiplication disabled)
#
# Skipped multiplication: ('87', '639') (multiplication disabled)
#
# Skipped multiplication: ('447', '139') (multiplication disabled)
#
# Skipped multiplication: ('862', '745') (multiplication disabled)
#
# Skipped multiplication: ('529', '136') (multiplication disabled)
#
# Skipped multiplication: ('203', '54') (multiplication disabled)
#
# Skipped multiplication: ('560', '419') (multiplication disabled)
#
# Skipped multiplication: ('617', '618') (multiplication disabled)
#
# Skipped multiplication: ('558', '602') (multiplication disabled)
#
# Skipped multiplication: ('376', '310') (multiplication disabled)
#
# Skipped multiplication: ('28', '566') (multiplication disabled)
#
# Skipped multiplication: ('943', '833') (multiplication disabled)
#
# Skipped multiplication: ('45', '58') (multiplication disabled)
#
# Skipped multiplication: ('651', '251') (multiplication disabled)
#
# Skipped multiplication: ('77', '14') (multiplication disabled)
#
# Skipped multiplication: ('526', '702') (multiplication disabled)
#
# Skipped multiplication: ('94', '187') (multiplication disabled)
#
# Skipped multiplication: ('442', '386') (multiplication disabled)
#
# Skipped multiplication: ('39', '93') (multiplication disabled)
#
# Skipped multiplication: ('216', '146') (multiplication disabled)
#
# Skipped multiplication: ('15', '638') (multiplication disabled)
#
# Skipped multiplication: ('109', '150') (multiplication disabled)
#
# Skipped multiplication: ('583', '727') (multiplication disabled)
#
# Skipped multiplication: ('628', '591') (multiplication disabled)
#
# Skipped multiplication: ('46', '848') (multiplication disabled)
#
# Skipped multiplication: ('746', '41') (multiplication disabled)
#
# Skipped multiplication: ('185', '512') (multiplication disabled)
#
# Skipped multiplication: ('696', '259') (multiplication disabled)
#
# Skipped multiplication: ('723', '454') (multiplication disabled)
#
# Skipped multiplication: ('666', '327') (multiplication disabled)
#
# Skipped multiplication: ('464', '555') (multiplication disabled)
#
# Skipped multiplication: ('594', '757') (multiplication disabled)
#
# Skipped multiplication: ('150', '180') (multiplication disabled)
#
# Skipped multiplication: ('862', '130') (multiplication disabled)
#
# Skipped multiplication: ('462', '469') (multiplication disabled)
#
# Skipped multiplication: ('975', '441') (multiplication disabled)
#
# Skipped multiplication: ('887', '237') (multiplication disabled)
#
# Skipped multiplication: ('44', '371') (multiplication disabled)
#
# Skipped multiplication: ('143', '829') (multiplication disabled)
#
# Skipped multiplication: ('416', '345') (multiplication disabled)
#
# Skipped multiplication: ('918', '333') (multiplication disabled)
#
# Skipped multiplication: ('114', '13') (multiplication disabled)
#
# Skipped multiplication: ('716', '42') (multiplication disabled)
#
# Skipped multiplication: ('789', '108') (multiplication disabled)
#
# Skipped multiplication: ('962', '293') (multiplication disabled)
#
# Skipped multiplication: ('235', '737') (multiplication disabled)
#
# Skipped multiplication: ('296', '722') (multiplication disabled)
#
# Skipped multiplication: ('820', '701') (multiplication disabled)
#
# Skipped multiplication: ('87', '546') (multiplication disabled)
#
# Skipped multiplication: ('301', '192') (multiplication disabled)
#
# Skipped multiplication: ('494', '214') (multiplication disabled)
#
# Skipped multiplication: ('56', '530') (multiplication disabled)
#
# Skipped multiplication: ('712', '266') (multiplication disabled)
#
# Skipped multiplication: ('368', '654') (multiplication disabled)
#
# Skipped multiplication: ('530', '635') (multiplication disabled)
#
# Skipped multiplication: ('842', '959') (multiplication disabled)
#
# Skipped multiplication: ('656', '546') (multiplication disabled)
#
# Skipped multiplication: ('174', '109') (multiplication disabled)
#
# Skipped multiplication: ('884', '560') (multiplication disabled)
#
# Skipped multiplication: ('486', '236') (multiplication disabled)
#
# Skipped multiplication: ('968', '157') (multiplication disabled)
#
# Skipped multiplication: ('326', '6') (multiplication disabled)
#
# Skipped multiplication: ('888', '954') (multiplication disabled)
#
# Skipped multiplication: ('284', '880') (multiplication disabled)
#
# Skipped multiplication: ('965', '969') (multiplication disabled)
#
# Skipped multiplication: ('208', '948') (multiplication disabled)
#
# Skipped multiplication: ('926', '7') (multiplication disabled)
#
# Skipped multiplication: ('381', '393') (multiplication disabled)
#
# Skipped multiplication: ('516', '776') (multiplication disabled)
#
# Skipped multiplication: ('787', '629') (multiplication disabled)
#
# Skipped multiplication: ('350', '247') (multiplication disabled)
#
# Skipped multiplication: ('849', '382') (multiplication disabled)
#
# Skipped multiplication: ('393', '781') (multiplication disabled)
#
# Skipped multiplication: ('989', '566') (multiplication disabled)
#
# Skipped multiplication: ('278', '341') (multiplication disabled)
#
# Skipped multiplication: ('222', '778') (multiplication disabled)
#
# Skipped multiplication: ('803', '159') (multiplication disabled)
#
# Skipped multiplication: ('691', '904') (multiplication disabled)
#
# Skipped multiplication: ('581', '426') (multiplication disabled)
#
# Skipped multiplication: ('328', '130') (multiplication disabled)
#
# Skipped multiplication: ('110', '46') (multiplication disabled)
#
# Skipped multiplication: ('838', '660') (multiplication disabled)
#
# Skipped multiplication: ('665', '204') (multiplication disabled)
#
# Skipped multiplication: ('214', '201') (multiplication disabled)
#
# Skipped multiplication: ('691', '782') (multiplication disabled)
#
# Skipped multiplication: ('479', '190') (multiplication disabled)
#
# Skipped multiplication: ('322', '468') (multiplication disabled)
#
# Skipped multiplication: ('374', '709') (multiplication disabled)
#
# Skipped multiplication: ('306', '137') (multiplication disabled)
#
# Skipped multiplication: ('273', '163') (multiplication disabled)
#
# Skipped multiplication: ('416', '188') (multiplication disabled)
#
# Added valid multiplication: ('783', '110')
#
# Skipped multiplication: ('725', '259') (multiplication disabled)
#
# Skipped multiplication: ('221', '543') (multiplication disabled)
#
# Skipped multiplication: ('857', '223') (multiplication disabled)
#
# Skipped multiplication: ('624', '83') (multiplication disabled)
#
# Skipped multiplication: ('300', '364') (multiplication disabled)
#
# Skipped multiplication: ('444', '866') (multiplication disabled)
#
# Skipped multiplication: ('7', '101') (multiplication disabled)
#
# Skipped multiplication: ('777', '568') (multiplication disabled)
#
# Skipped multiplication: ('424', '26') (multiplication disabled)
#
# Skipped multiplication: ('498', '501') (multiplication disabled)
#
# Skipped multiplication: ('653', '284') (multiplication disabled)
#
# Skipped multiplication: ('54', '515') (multiplication disabled)
#
# Skipped multiplication: ('674', '404') (multiplication disabled)
#
# Skipped multiplication: ('796', '988') (multiplication disabled)
#
# Skipped multiplication: ('707', '420') (multiplication disabled)
#
# Skipped multiplication: ('321', '951') (multiplication disabled)
#
# Skipped multiplication: ('26', '730') (multiplication disabled)
#
# Skipped multiplication: ('983', '348') (multiplication disabled)
#
# Skipped multiplication: ('737', '814') (multiplication disabled)
#
# Skipped multiplication: ('255', '877') (multiplication disabled)
#
# Skipped multiplication: ('39', '878') (multiplication disabled)
#
# Skipped multiplication: ('272', '144') (multiplication disabled)
#
# Skipped multiplication: ('650', '630') (multiplication disabled)
#
# Skipped multiplication: ('664', '129') (multiplication disabled)
#
# Skipped multiplication: ('516', '104') (multiplication disabled)
#
# Skipped multiplication: ('154', '967') (multiplication disabled)
#
# Skipped multiplication: ('842', '492') (multiplication disabled)
#
# Skipped multiplication: ('106', '811') (multiplication disabled)
#
# Skipped multiplication: ('880', '664') (multiplication disabled)
#
# Skipped multiplication: ('458', '922') (multiplication disabled)
#
# Skipped multiplication: ('142', '694') (multiplication disabled)
#
# Skipped multiplication: ('174', '57') (multiplication disabled)
#
# Skipped multiplication: ('388', '973') (multiplication disabled)
#
# Skipped multiplication: ('509', '257') (multiplication disabled)
#
# Skipped multiplication: ('799', '86') (multiplication disabled)
#
# Skipped multiplication: ('339', '727') (multiplication disabled)
#
# Skipped multiplication: ('494', '207') (multiplication disabled)
#
# Skipped multiplication: ('90', '205') (multiplication disabled)
#
# Skipped multiplication: ('544', '661') (multiplication disabled)
#
# Skipped multiplication: ('874', '856') (multiplication disabled)
#
# Skipped multiplication: ('599', '46') (multiplication disabled)
#
# Skipped multiplication: ('737', '434') (multiplication disabled)
#
# Skipped multiplication: ('407', '36') (multiplication disabled)
#
# Skipped multiplication: ('754', '560') (multiplication disabled)
#
# Skipped multiplication: ('560', '704') (multiplication disabled)
#
# Skipped multiplication: ('750', '987') (multiplication disabled)
#
# Skipped multiplication: ('70', '217') (multiplication disabled)
#
# Skipped multiplication: ('620', '489') (multiplication disabled)
#
# Skipped multiplication: ('628', '769') (multiplication disabled)
#
# Skipped multiplication: ('272', '344') (multiplication disabled)
#
# Skipped multiplication: ('248', '555') (multiplication disabled)
#
# Skipped multiplication: ('272', '890') (multiplication disabled)
#
# Skipped multiplication: ('372', '997') (multiplication disabled)
#
# Skipped multiplication: ('270', '900') (multiplication disabled)
#
# Skipped multiplication: ('519', '594') (multiplication disabled)
#
# Skipped multiplication: ('378', '725') (multiplication disabled)
#
# Skipped multiplication: ('375', '395') (multiplication disabled)
#
# Skipped multiplication: ('327', '383') (multiplication disabled)
#
# Skipped multiplication: ('512', '137') (multiplication disabled)
#
# Skipped multiplication: ('322', '146') (multiplication disabled)
#
# Skipped multiplication: ('507', '405') (multiplication disabled)
#
# Skipped multiplication: ('648', '445') (multiplication disabled)
#
# Skipped multiplication: ('420', '480') (multiplication disabled)
#
# Skipped multiplication: ('621', '94') (multiplication disabled)
#
# Added valid multiplication: ('180', '357')
#
# Added valid multiplication: ('855', '209')
#
# Added valid multiplication: ('183', '292')
#
# Added valid multiplication: ('124', '303')
#
# Added valid multiplication: ('200', '399')
#
# Added valid multiplication: ('201', '772')
#
# Added valid multiplication: ('251', '924')
#
# Added valid multiplication: ('552', '184')
#
# Skipped multiplication: ('940', '413') (multiplication disabled)
#
# Skipped multiplication: ('478', '154') (multiplication disabled)
#
# Skipped multiplication: ('126', '487') (multiplication disabled)
#
# Skipped multiplication: ('231', '424') (multiplication disabled)
#
# Skipped multiplication: ('421', '910') (multiplication disabled)
#
# Skipped multiplication: ('571', '861') (multiplication disabled)
#
# Skipped multiplication: ('13', '20') (multiplication disabled)
#
# Added valid multiplication: ('938', '229')
#
# Added valid multiplication: ('997', '397')
#
# Added valid multiplication: ('775', '374')
#
# Added valid multiplication: ('32', '605')
#
# Added valid multiplication: ('74', '333')
#
# Added valid multiplication: ('179', '40')
#
# Added valid multiplication: ('68', '331')
#
# Added valid multiplication: ('201', '802')
#
# Added valid multiplication: ('578', '390')
#
# Added valid multiplication: ('175', '690')
#
# Added valid multiplication: ('381', '285')
#
# Added valid multiplication: ('19', '146')
#
# Added valid multiplication: ('327', '506')
#
# Added valid multiplication: ('170', '681')
#
# Added valid multiplication: ('422', '557')
#
# Added valid multiplication: ('389', '988')
#
# Added valid multiplication: ('893', '97')
#
# Added valid multiplication: ('352', '901')
#
# Added valid multiplication: ('888', '683')
#
# Added valid multiplication: ('355', '339')
#
# Added valid multiplication: ('39', '219')
#
# Added valid multiplication: ('737', '401')
#
# Added valid multiplication: ('270', '667')
#
# Added valid multiplication: ('227', '88')
#
# Added valid multiplication: ('669', '526')
#
# Added valid multiplication: ('571', '401')
#
# Added valid multiplication: ('261', '80')
#
# Added valid multiplication: ('652', '169')
#
# Added valid multiplication: ('313', '890')
#
# Added valid multiplication: ('879', '799')
#
# Skipped multiplication: ('976', '237') (multiplication disabled)
#
# Skipped multiplication: ('626', '238') (multiplication disabled)
#
# Skipped multiplication: ('519', '346') (multiplication disabled)
#
# Skipped multiplication: ('177', '983') (multiplication disabled)
#
# Skipped multiplication: ('361', '158') (multiplication disabled)
#
# Skipped multiplication: ('324', '188') (multiplication disabled)
#
# Skipped multiplication: ('964', '296') (multiplication disabled)
#
# Skipped multiplication: ('118', '159') (multiplication disabled)
#
# Skipped multiplication: ('825', '887') (multiplication disabled)
#
# Skipped multiplication: ('332', '673') (multiplication disabled)
#
# Skipped multiplication: ('401', '574') (multiplication disabled)
#
# Added valid multiplication: ('961', '847')
#
# Added valid multiplication: ('188', '129')
#
# Added valid multiplication: ('241', '300')
#
# Added valid multiplication: ('661', '107')
#
# Added valid multiplication: ('232', '615')
#
# Added valid multiplication: ('318', '851')
#
# Added valid multiplication: ('841', '48')
#
# Added valid multiplication: ('65', '11')
#
# Added valid multiplication: ('72', '261')
#
# Added valid multiplication: ('963', '435')
#
# Added valid multiplication: ('261', '650')
#
# Added valid multiplication: ('524', '801')
#
# Added valid multiplication: ('827', '329')
#
# Added valid multiplication: ('643', '136')
#
# Added valid multiplication: ('767', '938')
#
# Added valid multiplication: ('869', '563')
#
# Added valid multiplication: ('413', '336')
#
# Added valid multiplication: ('278', '437')
#
# Added valid multiplication: ('668', '195')
#
# Added valid multiplication: ('75', '218')
#
# Skipped multiplication: ('14', '953') (multiplication disabled)
#
# Skipped multiplication: ('411', '667') (multiplication disabled)
#
# Skipped multiplication: ('229', '712') (multiplication disabled)
#
# Skipped multiplication: ('807', '219') (multiplication disabled)
#
# Skipped multiplication: ('100', '188') (multiplication disabled)
#
# Skipped multiplication: ('960', '272') (multiplication disabled)
#
# Skipped multiplication: ('453', '41') (multiplication disabled)
#
# Skipped multiplication: ('372', '322') (multiplication disabled)
#
# Skipped multiplication: ('234', '505') (multiplication disabled)
#
# Skipped multiplication: ('717', '42') (multiplication disabled)
#
# Skipped multiplication: ('883', '914') (multiplication disabled)
#
# Skipped multiplication: ('443', '81') (multiplication disabled)
#
# Skipped multiplication: ('954', '201') (multiplication disabled)
#
# Skipped multiplication: ('448', '507') (multiplication disabled)
#
# Skipped multiplication: ('745', '138') (multiplication disabled)
#
# Skipped multiplication: ('631', '868') (multiplication disabled)
#
# Skipped multiplication: ('285', '681') (multiplication disabled)
#
# Skipped multiplication: ('682', '788') (multiplication disabled)
#
# Skipped multiplication: ('994', '408') (multiplication disabled)
#
# Skipped multiplication: ('214', '829') (multiplication disabled)
#
# Skipped multiplication: ('340', '580') (multiplication disabled)
#
# Skipped multiplication: ('130', '659') (multiplication disabled)
#
# Added valid multiplication: ('214', '73')
#
# Added valid multiplication: ('371', '280')
#
# Added valid multiplication: ('964', '116')
#
# Skipped multiplication: ('904', '24') (multiplication disabled)
#
# Skipped multiplication: ('770', '531') (multiplication disabled)
#
# Skipped multiplication: ('539', '562') (multiplication disabled)
#
# Skipped multiplication: ('239', '254') (multiplication disabled)
#
# Skipped multiplication: ('489', '900') (multiplication disabled)
#
# Skipped multiplication: ('192', '300') (multiplication disabled)
#
# Skipped multiplication: ('924', '577') (multiplication disabled)
#
# Skipped multiplication: ('956', '98') (multiplication disabled)
#
# Skipped multiplication: ('954', '868') (multiplication disabled)
#
# Skipped multiplication: ('288', '439') (multiplication disabled)
#
# Skipped multiplication: ('636', '151') (multiplication disabled)
#
# Skipped multiplication: ('235', '489') (multiplication disabled)
#
# Skipped multiplication: ('718', '994') (multiplication disabled)
#
# Skipped multiplication: ('359', '893') (multiplication disabled)
#
# Skipped multiplication: ('277', '807') (multiplication disabled)
#
# Skipped multiplication: ('727', '217') (multiplication disabled)
#
# Skipped multiplication: ('344', '407') (multiplication disabled)
#
# Skipped multiplication: ('876', '612') (multiplication disabled)
#
# Skipped multiplication: ('241', '755') (multiplication disabled)
#
# Skipped multiplication: ('593', '943') (multiplication disabled)
#
# Skipped multiplication: ('219', '895') (multiplication disabled)
#
# Skipped multiplication: ('771', '75') (multiplication disabled)
#
# Skipped multiplication: ('903', '219') (multiplication disabled)
#
# Skipped multiplication: ('705', '739') (multiplication disabled)
#
# Skipped multiplication: ('692', '511') (multiplication disabled)
#
# Skipped multiplication: ('846', '763') (multiplication disabled)
#
# Skipped multiplication: ('941', '842') (multiplication disabled)
#
# Skipped multiplication: ('384', '840') (multiplication disabled)
#
# Skipped multiplication: ('656', '250') (multiplication disabled)
#
# Skipped multiplication: ('892', '589') (multiplication disabled)
#
# Skipped multiplication: ('611', '673') (multiplication disabled)
#
# Skipped multiplication: ('740', '383') (multiplication disabled)
#
# Skipped multiplication: ('754', '363') (multiplication disabled)
#
# Skipped multiplication: ('815', '158') (multiplication disabled)
#
# Skipped multiplication: ('413', '854') (multiplication disabled)
#
# Skipped multiplication: ('102', '232') (multiplication disabled)
#
# Skipped multiplication: ('232', '717') (multiplication disabled)
#
# Skipped multiplication: ('177', '872') (multiplication disabled)
#
# Skipped multiplication: ('393', '711') (multiplication disabled)
#
# Skipped multiplication: ('909', '998') (multiplication disabled)
#
# Skipped multiplication: ('177', '274') (multiplication disabled)
#
# Final list of valid multiplications: [('28', '510'), ('276', '283'), ('181', '314'), ('314', '733'), ('457', '651'), ('279', '135'), ('579', '740'), ('515', '329'), ('508', '45'), ('299', '897'), ('948', '555'), ('137', '832'), ('243', '401'), ('71', '774'), ('172', '268'), ('758', '223'), ('49', '326'), ('786', '646'), ('841', '587'), ('981', '592'), ('296', '234'), ('714', '304'), ('757', '667'), ('12', '277'), ('540', '166'), ('286', '138'), ('770', '494'), ('457', '109'), ('436', '361'), ('899', '657'), ('965', '550'), ('16', '267'), ('305', '656'), ('795', '461'), ('647', '388'), ('944', '963'), ('856', '379'), ('185', '846'), ('460', '898'), ('229', '900'), ('990', '969'), ('927', '423'), ('827', '259'), ('771', '396'), ('31', '548'), ('186', '978'), ('893', '833'), ('151', '691'), ('117', '662'), ('609', '660'), ('920', '151'), ('148', '463'), ('394', '10'), ('692', '431'), ('148', '193'), ('467', '891'), ('694', '600'), ('326', '593'), ('485', '524'), ('330', '946'), ('377', '867'), ('410', '38'), ('557', '508'), ('296', '240'), ('269', '24'), ('444', '457'), ('42', '768'), ('425', '243'), ('958', '793'), ('973', '632'), ('870', '593'), ('745', '223'), ('181', '897'), ('673', '429'), ('102', '654'), ('536', '134'), ('862', '564'), ('573', '681'), ('469', '457'), ('305', '833'), ('56', '269'), ('156', '371'), ('538', '775'), ('376', '766'), ('605', '700'), ('709', '480'), ('56', '9'), ('41', '872'), ('533', '809'), ('473', '210'), ('828', '843'), ('288', '143'), ('991', '738'), ('547', '808'), ('232', '866'), ('179', '173'), ('153', '382'), ('386', '581'), ('914', '537'), ('694', '671'), ('423', '141'), ('475', '67'), ('801', '43'), ('323', '862'), ('575', '460'), ('328', '263'), ('68', '15'), ('430', '387'), ('146', '810'), ('261', '638'), ('968', '916'), ('392', '73'), ('283', '731'), ('533', '13'), ('128', '902'), ('358', '310'), ('845', '59'), ('466', '598'), ('462', '461'), ('102', '119'), ('295', '640'), ('238', '80'), ('743', '854'), ('471', '909'), ('69', '900'), ('856', '5'), ('521', '403'), ('156', '80'), ('612', '943'), ('209', '98'), ('866', '416'), ('190', '400'), ('243', '292'), ('497', '592'), ('890', '938'), ('384', '970'), ('662', '264'), ('907', '796'), ('819', '58'), ('962', '712'), ('967', '248'), ('142', '596'), ('300', '181'), ('688', '281'), ('393', '337'), ('86', '734'), ('680', '335'), ('525', '510'), ('273', '72'), ('874', '891'), ('395', '446'), ('883', '551'), ('840', '262'), ('593', '805'), ('458', '211'), ('804', '650'), ('708', '773'), ('987', '695'), ('130', '150'), ('311', '404'), ('382', '827'), ('128', '276'), ('963', '658'), ('107', '773'), ('851', '408'), ('84', '253'), ('207', '430'), ('727', '290'), ('629', '48'), ('437', '164'), ('520', '790'), ('783', '110'), ('180', '357'), ('855', '209'), ('183', '292'), ('124', '303'), ('200', '399'), ('201', '772'), ('251', '924'), ('552', '184'), ('938', '229'), ('997', '397'), ('775', '374'), ('32', '605'), ('74', '333'), ('179', '40'), ('68', '331'), ('201', '802'), ('578', '390'), ('175', '690'), ('381', '285'), ('19', '146'), ('327', '506'), ('170', '681'), ('422', '557'), ('389', '988'), ('893', '97'), ('352', '901'), ('888', '683'), ('355', '339'), ('39', '219'), ('737', '401'), ('270', '667'), ('227', '88'), ('669', '526'), ('571', '401'), ('261', '80'), ('652', '169'), ('313', '890'), ('879', '799'), ('961', '847'), ('188', '129'), ('241', '300'), ('661', '107'), ('232', '615'), ('318', '851'), ('841', '48'), ('65', '11'), ('72', '261'), ('963', '435'), ('261', '650'), ('524', '801'), ('827', '329'), ('643', '136'), ('767', '938'), ('869', '563'), ('413', '336'), ('278', '437'), ('668', '195'), ('75', '218'), ('214', '73'), ('371', '280'), ('964', '116')]
#
# Total sum of all multiplications: 53783319
#
# Final result: 53783319
